# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic'

# %%
r = requests.get(url)
html = r.content
soup = BeautifulSoup(html, 'lxml')
wiki_tables = soup.findAll('table', 'sortable')[0]

# %%
table_rows = wiki_tables.find_all('tr')
table_headers = wiki_tables.find_all('th')
table_headers
# Out:
# [<th>Rank</th>,
#  <th>Airport</th>,
#  <th>Location</th>,
#  <th>Country</th>,
#  <th>Code<br/>(IATA/ICAO)</th>,
#  <th>Half-year<br/>passengers</th>,
#  <th>Rank<br/>change</th>,
#  <th>%<br/>Change
#  </th>]

# %%
l = []
for tr in table_rows:
    td = tr.find_all(['td','th'])
    row = [tr.text for tr in td]
    l.append(row)
l[0:2]
# Out:
# [['Rank',
#   'Airport',
#   'Location',
#   'Country',
#   'Code(IATA/ICAO)',
#   'Half-yearpassengers',
#   'Rankchange',
#   '%Change\n'],
#  ['1.',
#   ' Hartsfield–Jackson Atlanta International Airport',
#   'Atlanta, Georgia',
#   'United States',
#   'ATL/KATL',
#   '54,388,000',
#   '',
#   '3.3%\n']]

# %%
# df = pd.DataFrame(l, columns=table_headers)
df = pd.DataFrame(l)
df.head()
# Out:
#       0                                                  1  \
# 0  Rank                                            Airport
# 1    1.   Hartsfield–Jackson Atlanta International Airport
# 2    2.              Beijing Capital International Airport
# 3    3.                  Los Angeles International Airport
# 4    4.                               Tokyo Haneda Airport
#
#                           2              3                4  \
# 0                  Location        Country  Code(IATA/ICAO)
# 1          Atlanta, Georgia  United States         ATL/KATL
# 2  Chaoyang-Shunyi, Beijing          China         PEK/ZBAA
# 3   Los Angeles, California  United States         LAX/KLAX
# 4                Ōta, Tokyo          Japan         HND/RJTT
#
#                      5           6          7
# 0  Half-yearpassengers  Rankchange  %Change\n
# 1           54,388,000                 3.3%\n
# 2           49,242,000                 0.6%\n
# 3           43,049,000           1     0.9%\n
# 4           41,435,000           1     1.1%\n

# %%
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header
df.head()
# Out:
# 0 Rank                                            Airport  \
# 1   1.   Hartsfield–Jackson Atlanta International Airport
# 2   2.              Beijing Capital International Airport
# 3   3.                  Los Angeles International Airport
# 4   4.                               Tokyo Haneda Airport
# 5   5.                        Dubai International Airport
#
# 0                  Location               Country Code(IATA/ICAO)  \
# 1          Atlanta, Georgia         United States        ATL/KATL
# 2  Chaoyang-Shunyi, Beijing                 China        PEK/ZBAA
# 3   Los Angeles, California         United States        LAX/KLAX
# 4                Ōta, Tokyo                 Japan        HND/RJTT
# 5            Garhoud, Dubai  United Arab Emirates        DXB/OMDB
#
# 0 Half-yearpassengers Rankchange %Change\n
# 1          54,388,000               3.3%\n
# 2          49,242,000               0.6%\n
# 3          43,049,000          1    0.9%\n
# 4          41,435,000          1    1.1%\n
# 5          41,278,000          2    5.6%\n

# %%
df['Half-yearpassengers'] = df['Half-yearpassengers'].str.replace(',','')

# %%
df['Half-yearpassengers'] = df['Half-yearpassengers'].convert_objects(convert_numeric=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
# 24            San Mateo County, California         United States
# 25       Shuangliu-Wuhou, Chengdu, Sichuan                 China
# 26             Bao'an, Shenzhen, Guangdong                 China
# 27                        Orlando, Florida         United States
# 28                       Las Vegas, Nevada         United States
# 29                               Barcelona                 Spain
# 30                    Mississauga, Ontario                Canada
#
# 0  Code(IATA/ICAO)  Half-yearpassengers Rankchange %Change\n
# 1         ATL/KATL           54388000.0               3.3%\n
# 2         PEK/ZBAA           49242000.0               0.6%\n
# 3         LAX/KLAX           43049000.0          1    0.9%\n
# 4         HND/RJTT           41435000.0          1    1.1%\n
# 5         DXB/OMDB           41278000.0          2    5.6%\n
# 6         ORD/KORD           39512000.0               2.8%\n
# 7         LHR/EGLL           38750000.0               1.8%\n
# 8         PVG/ZSPD           38220000.0          1    4.2%\n
# 9         HKG/VHHH           37800000.0          1    2.5%\n
# 10        CDG/LFPG           36339000.0               7.2%\n
# 11        DFW/KDFW           36122000.0          4    6.3%\n
# 12        CAN/ZGGG           35646000.0          1    4.1%\n
# 13        ICN/RKSI           35547000.0          3    5.7%\n
# 14        AMS/EHAM           34537000.0          3    1.4%\n
# 15        FRA/EDDF           33644000.0          1    3.0%\n
# 16        SIN/WSSS           33190000.0          3    3.4%\n
# 17        BKK/VTBS           32760000.0          4    2.5%\n
# 18        DEN/KDEN           32705000.0          2    6.1%\n
# 19        DEL/VIDP           32558857.0          7    7.4%\n
# 20        CGK/WIII                  NaN          1        \n
# 21        JFK/KJFK           30481000.0          2    4.4%\n
# 22        KUL/WMKK           30355000.0          2    2.0%\n
# 23        MAD/LEMD           29284000.0          2    6.6%\n
# 24        SFO/KSFO           27704000.0          2    0.8%\n
# 25        CTU/ZUUU           27340000.0          2    4.7%\n
# 26        SZX/ZGSZ           25837000.0          6    6.2%\n
# 27        MCO/KMCO           25800000.0          7    6.7%\n
# 28        LAS/KLAS           25274000.0          2    3.1%\n
# 29        BCN/LEBL           24821000.0          2    5.5%\n
# 30        YYZ/CYYZ           24463000.0          1    3.1%\n

# %%
df['Half-yearpassengers'] = df['Half-yearpassengers'].astype(float)

# %%
df.groupby('Country')['Half-yearpassengers'].sum()
# Out:
# Country
# Canada                   24463000.0
# China                   176285000.0
# France                   36339000.0
# Germany                  33644000.0
# Hong Kong SAR, China     37800000.0
# India                    32558857.0
# Indonesia                       0.0
# Japan                    41435000.0
# Malaysia                 30355000.0
# Republic of Korea        35547000.0
# Singapore                33190000.0
# Spain                    54105000.0
# Thailand                 32760000.0
# The Netherlands          34537000.0
# United Arab Emirates     41278000.0
# United Kingdom           38750000.0
# United States           315035000.0
# Name: Half-yearpassengers, dtype: float64
